# %% [markdown]
# <a href="https://colab.research.google.com/github/Thialves02/blueEdtech-mod1/blob/main/Exercicios_While.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
sexo = input("Digite seu sexo [M/F]").upper()
while sexo!="M" and sexo!="F":
  print("\nDigite corretamente")
  sexo = input("Digite seu sexo [M/F]").upper()
if sexo == "F":
  print("Seu sexo é feminino")
else:
  print("Seu sexo é masculino")
# Out:
# Digite seu sexo [M/F]a
#
# Digite corretamente
# Digite seu sexo [M/F]a
#
# Digite corretamente
# Digite seu sexo [M/F]f
# Seu sexo é feminino

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %%
senha = "Blue123"
qntd = 0

var = input("Digite a senha = ")
while var!= senha:
  var = input("\nSenha incorreta\nDigite a senha novamente = ")
  qntd+=1
print("\nBem vindo ao portal")
print("Você errou a senha",qntd,"vezes.")
# Out:
# Digite a senha = a
#
# Senha incorreta
# Digite a senha novamente = a
#
# Senha incorreta
# Digite a senha novamente = a
#
# Senha incorreta
# Digite a senha novamente = a
#
# Senha incorreta
# Digite a senha novamente = Blue123
#
# Bem vindo ao portal
# Você errou a senha 4 vezes

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %%
idade = int(input("Qual a sua idade? = "))
sexo = input("Qual seu sexo [M/F]? = ").upper()
pergunta = input("Deseja fazer outro cadastro [S/N]? = ").upper()
print("")
maior = 0
homem = 0
mulher20 = 0
if idade>18:
    maior+=1
if sexo == "M":
    homem +=1
if sexo == "F" and idade < 20:
    mulher20 = mulher20 + 1
    
while pergunta == "S":
  idade = int(input("Qual a sua idade? = "))
  sexo = input("Qual seu sexo [M/F]? = ").upper()
  pergunta = input("Deseja fazer outro cadastro [S/N]? = ").upper()
  print("")
  if idade>18:
    maior+=1
  if sexo == "M":
    homem +=1
  if sexo == "F" and idade < 20:
    mulher20 = mulher20 + 1

print(maior,"pessoas tem mais de 18 anos.")
print(homem,"homens foram cadastrados")
print(mulher20,"mulheres tem menos de 20 anos")
# Out:
# Qual a sua idade? = 55
# Qual seu sexo [M/F]? = m
# Deseja fazer outro cadastro [S/N]? = s
#
# Qual a sua idade? = 55
# Qual seu sexo [M/F]? = m
# Deseja fazer outro cadastro [S/N]? = s
#
# Qual a sua idade? = 10
# Qual seu sexo [M/F]? = f
# Deseja fazer outro cadastro [S/N]? = n
#
# 2 pessoas tem mais de 18 anos.
# 2 homens foram cadastrados
# 1 mulheres tem menos de 20 anos

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %%
from random import randint

rand = (randint(0,10))
num = int(input("Digite um número = "))
qntd = 1
print("O número era",rand)
print("")
while num!=rand:
  rand = (randint(0,10))
  num = int(input("Digite um número = "))
  qntd = qntd + 1
  print("O número era",rand)
  print("")
print("Você acertou!!!")
print(qntd,"foram necessárias para você acertar")
# Out:
# Digite um número = 5
# O número era 2
#
# Digite um número = 5
# O número era 3
#
# Digite um número = 5
# O número era 5
#
# Você acertou!!!
# 3 foram necessárias para você acertar
